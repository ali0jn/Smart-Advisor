# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('original_dataset.csv')
df = df.rename(columns={'Kod': 'Course Code', 'Tanım': 'Course Title', 'Öğrenci No': 'Student Number', 'Bölüm': 'Department Code', 'Bölüm (tanım)': 'Course Level', 'Not': 'Letter Grade', 'Kayıt drm.': 'Status', 'Dönem': 'Semester'})
df.drop('Skala', axis=1, inplace=True)
df
# Out:
#       Course Code                              Course Title  Student Number  \
# 0          IE 316                     Engineering Economics             713
# 1         MGT 201                  Principles of Management             713
# 2        PHYS 104  Physics II-Electromagnetics & Modern phy             713
# 3         UNI 123       Textual Analysis and Effective Com.             713
# 4        ENGR 244                     Engineering Materials             713
# ...           ...                                       ...             ...
# 55470     ITM 406                  Global Business Strategy            2315
# 55471     UNI 116     Turkish for International Students II            2315
# 55472    ENGR 105               Introduction to Engineering            2315
# 55473      CS 100         Int. to Computer Science and Eng.            2315
# 55474    ENGR 100                           Computer Skills            2315
#
#       Department Code                           Course Level Letter Grade  \
# 0                  IE  Endüstri Mühendisliği Lisans Programı            A
# 1                 ITM   Uluslararası Ticaret ve İşletmecilik            A
# 2                  IE  Endüstri Mühendisliği Lisans Programı            A
# 3                  IE  Endüstri Mühendisliği Lisans Programı            A
# 4                  IE  Endüstri Mühendisliği Lisans Programı           A-
# ...               ...                                    ...          ...
# 55470             MGT                İşletme Lisans Programı            C
# 55471             MGT                İşletme Lisans Programı           C+
# 55472             MGT                İşletme Lisans Programı           IA
# 55473             MGT                İşletme Lisans Programı            S
# 55474             MGT                İşletme Lisans Programı            S
#
#                      Status      Semester
# 0      Başarıyla tamamlandı  2014 - Bahar
# 1      Başarıyla tamamlandı    2013 - Güz
# 2      Başarıyla tamamlandı  2012 - Bahar
# 3      Başarıyla tamamlandı  2012 - Bahar
# 4      Başarıyla tamamlandı  2013 - Bahar
# ...                     ...           ...
# 55470  Başarıyla tamamlandı  2014 - Bahar
# 55471  Başarıyla tamamlandı  2014 - Bahar
# 55472  Başarısız tamamlandı  2014 - Bahar
# 55473  Başarıyla tamamlandı  2014 - Bahar
# 55474  Başarıyla tamamlandı  2014 - Bahar
#
# [55475 rows x 8 columns]

# %%
df.insert(2, 'Course Year', '1')
for row_idx in df.index:
    course_code = df.iloc[row_idx, 0]
    if course_code.split()[1][0] in ['1', '2', '3', '4']:
        df.iloc[row_idx, 5] = 'Undergraduate'
    elif course_code.split()[1][0] in ['5', '6']:
        df.iloc[row_idx, 5] = 'Graduate'
    else:
        df.iloc[row_idx, 5] = 'PhD'
df
# Out:
#       Course Code                              Course Title Course Year  \
# 0          IE 316                     Engineering Economics           1
# 1         MGT 201                  Principles of Management           1
# 2        PHYS 104  Physics II-Electromagnetics & Modern phy           1
# 3         UNI 123       Textual Analysis and Effective Com.           1
# 4        ENGR 244                     Engineering Materials           1
# ...           ...                                       ...         ...
# 55470     ITM 406                  Global Business Strategy           1
# 55471     UNI 116     Turkish for International Students II           1
# 55472    ENGR 105               Introduction to Engineering           1
# 55473      CS 100         Int. to Computer Science and Eng.           1
# 55474    ENGR 100                           Computer Skills           1
#
#        Student Number Department Code   Course Level Letter Grade  \
# 0                 713              IE  Undergraduate            A
# 1                 713             ITM  Undergraduate            A
# 2                 713              IE  Undergraduate            A
# 3                 713              IE  Undergraduate            A
# 4                 713              IE  Undergraduate           A-
# ...               ...             ...            ...          ...
# 55470            2315             MGT  Undergraduate            C
# 55471            2315             MGT  Undergraduate           C+
# 55472            2315             MGT  Undergraduate           IA
# 55473            2315             MGT  Undergraduate            S
# 55474            2315             MGT  Undergraduate            S
#
#                      Status      Semester
# 0      Başarıyla tamamlandı  2014 - Bahar
# 1      Başarıyla tamamlandı    2013 - Güz
# 2      Başarıyla tamamlandı  2012 - Bahar
# 3      Başarıyla tamamlandı  2012 - Bahar
# 4      Başarıyla tamamlandı  2013 - Bahar
# ...                     ...           ...
# 55470  Başarıyla tamamlandı  2014 - Bahar
# 55471  Başarıyla tamamlandı  2014 - Bahar
# 55472  Başarısız tamamlandı  2014 - Bahar
# 55473  Başarıyla tamamlandı  2014 - Bahar
# 55474  Başarıyla tamamlandı  2014 - Bahar
#
# [55475 rows x 9 columns]

# %%
for row_idx in df.index:
    semester_name = df.iloc[row_idx, 8].split(' - ')
    if semester_name[1] == 'Güz':
        df.iloc[row_idx, 8] = semester_name[0] + ' - ' + 'Fall'
    elif semester_name[1] == 'Bahar':
        df.iloc[row_idx, 8] = semester_name[0] + ' - ' + 'Spring'
    else:
        df.iloc[row_idx, 8] = semester_name[0] + ' - ' + 'Summer'
df
# Out:
#       Course Code                              Course Title Course Year  \
# 0          IE 316                     Engineering Economics           1
# 1         MGT 201                  Principles of Management           1
# 2        PHYS 104  Physics II-Electromagnetics & Modern phy           1
# 3         UNI 123       Textual Analysis and Effective Com.           1
# 4        ENGR 244                     Engineering Materials           1
# ...           ...                                       ...         ...
# 55470     ITM 406                  Global Business Strategy           1
# 55471     UNI 116     Turkish for International Students II           1
# 55472    ENGR 105               Introduction to Engineering           1
# 55473      CS 100         Int. to Computer Science and Eng.           1
# 55474    ENGR 100                           Computer Skills           1
#
#        Student Number Department Code   Course Level Letter Grade  \
# 0                 713              IE  Undergraduate            A
# 1                 713             ITM  Undergraduate            A
# 2                 713              IE  Undergraduate            A
# 3                 713              IE  Undergraduate            A
# 4                 713              IE  Undergraduate           A-
# ...               ...             ...            ...          ...
# 55470            2315             MGT  Undergraduate            C
# 55471            2315             MGT  Undergraduate           C+
# 55472            2315             MGT  Undergraduate           IA
# 55473            2315             MGT  Undergraduate            S
# 55474            2315             MGT  Undergraduate            S
#
#                      Status       Semester
# 0      Başarıyla tamamlandı  2014 - Spring
# 1      Başarıyla tamamlandı    2013 - Fall
# 2      Başarıyla tamamlandı  2012 - Spring
# 3      Başarıyla tamamlandı  2012 - Spring
# 4      Başarıyla tamamlandı  2013 - Spring
# ...                     ...            ...
# 55470  Başarıyla tamamlandı  2014 - Spring
# 55471  Başarıyla tamamlandı  2014 - Spring
# 55472  Başarısız tamamlandı  2014 - Spring
# 55473  Başarıyla tamamlandı  2014 - Spring
# 55474  Başarıyla tamamlandı  2014 - Spring
#
# [55475 rows x 9 columns]

# %%
for row_idx in df.index:
    if df.iloc[row_idx, 7] == 'Başarıyla tamamlandı':
        df.iloc[row_idx, 7] = 'Successful'
    elif df.iloc[row_idx, 7] == 'Başarısız tamamlandı':
        df.iloc[row_idx, 7] = 'Unsuccessful'
    else:
        df.iloc[row_idx, 7] = 'Recorded'
df
# Out:
#       Course Code                              Course Title Course Year  \
# 0          IE 316                     Engineering Economics           1
# 1         MGT 201                  Principles of Management           1
# 2        PHYS 104  Physics II-Electromagnetics & Modern phy           1
# 3         UNI 123       Textual Analysis and Effective Com.           1
# 4        ENGR 244                     Engineering Materials           1
# ...           ...                                       ...         ...
# 55470     ITM 406                  Global Business Strategy           1
# 55471     UNI 116     Turkish for International Students II           1
# 55472    ENGR 105               Introduction to Engineering           1
# 55473      CS 100         Int. to Computer Science and Eng.           1
# 55474    ENGR 100                           Computer Skills           1
#
#        Student Number Department Code   Course Level Letter Grade  \
# 0                 713              IE  Undergraduate            A
# 1                 713             ITM  Undergraduate            A
# 2                 713              IE  Undergraduate            A
# 3                 713              IE  Undergraduate            A
# 4                 713              IE  Undergraduate           A-
# ...               ...             ...            ...          ...
# 55470            2315             MGT  Undergraduate            C
# 55471            2315             MGT  Undergraduate           C+
# 55472            2315             MGT  Undergraduate           IA
# 55473            2315             MGT  Undergraduate            S
# 55474            2315             MGT  Undergraduate            S
#
#              Status       Semester
# 0        Successful  2014 - Spring
# 1        Successful    2013 - Fall
# 2        Successful  2012 - Spring
# 3        Successful  2012 - Spring
# 4        Successful  2013 - Spring
# ...             ...            ...
# 55470    Successful  2014 - Spring
# 55471    Successful  2014 - Spring
# 55472  Unsuccessful  2014 - Spring
# 55473    Successful  2014 - Spring
# 55474    Successful  2014 - Spring
#
# [55475 rows x 9 columns]

# %%
course_df = pd.read_csv('course_details_1.csv')
course_df
# Out:
#                                          Department Name Course Code  \
# 0      Political Science and International Relations ...     SYS 402
# 1      Political Science and International Relations ...    POLS 402
# 2                     Psychology Department (in Turkish)     PSI 402
# 3                     Psychology Department (in English)     PSY 414
# 4                                   Sociology Department     SOC 458
# ...                                                  ...         ...
# 15422                                     Graphic Design     ODP 205
# 15423                                     Graphic Design     ODP 206
# 15424                                     Graphic Design     ODP 207
# 15425                                     Graphic Design     ODP 208
# 15426                                     Graphic Design     ODP 209
#
#                              Course Title                       Type  \
# 0                  Turkish Foreign Policy                   Required
# 1                  Turkish Foreign Policy                   Required
# 2          Psikolojide Tarih ve Sistemler                   Required
# 3       History and Systems in Psychology                   Required
# 4                    Historical Sociology                   Required
# ...                                   ...                        ...
# 15422                   Kurumsal İletişim  ODP XXX Alan Dışı Seçmeli
# 15423                    Entrepreneurship  ODP XXX Alan Dışı Seçmeli
# 15424                    Public Relations  ODP XXX Alan Dışı Seçmeli
# 15425                           New Media  ODP XXX Alan Dışı Seçmeli
# 15426  Effective Communication Techniques  ODP XXX Alan Dışı Seçmeli
#
#                   Prerequisites  Theoritical  Practical  Course Credits  ECTS
# 0                       SYS 202            3          0               3     6
# 1                      POLS 202            3          0               3     6
# 2      At Least Success 68 Crh.            3          0               3     6
# 3                           NaN            3          0               3     6
# 4                           NaN            3          0               3     6
# ...                         ...          ...        ...             ...   ...
# 15422                       NaN            2          0               2     3
# 15423                       NaN            2          0               2     3
# 15424                       NaN            2          0               2     3
# 15425                       NaN            2          0               2     3
# 15426                       NaN            2          0               2     3
#
# [15427 rows x 9 columns]

# %%
course_df.drop_duplicates(subset=['Course Code'], inplace=True)
course_df.index = range(len(course_df))
course_df
# Out:
#                                         Department Name Course Code  \
# 0     Political Science and International Relations ...     SYS 402
# 1     Political Science and International Relations ...    POLS 402
# 2                    Psychology Department (in Turkish)     PSI 402
# 3                    Psychology Department (in English)     PSY 414
# 4                                  Sociology Department     SOC 458
# ...                                                 ...         ...
# 1373                     Public Relations and Publicity     ODP 206
# 1374                     Public Relations and Publicity     ODP 207
# 1375                     Public Relations and Publicity     ODP 208
# 1376                     Public Relations and Publicity     ODP 209
# 1377                                    Social Services         NaN
#
#                             Course Title                      Type  \
# 0                 Turkish Foreign Policy                  Required
# 1                 Turkish Foreign Policy                  Required
# 2         Psikolojide Tarih ve Sistemler                  Required
# 3      History and Systems in Psychology                  Required
# 4                   Historical Sociology                  Required
# ...                                  ...                       ...
# 1373                    Entrepreneurship         Alan Dışı Seçmeli
# 1374                    Public Relations         Alan Dışı Seçmeli
# 1375                           New Media         Alan Dışı Seçmeli
# 1376  Effective Communication Techniques         Alan Dışı Seçmeli
# 1377                                 NaN  SOP XXX Bölüm Seçmeli II
#
#                  Prerequisites  Theoritical  Practical  Course Credits  ECTS
# 0                      SYS 202            3          0               3     6
# 1                     POLS 202            3          0               3     6
# 2     At Least Success 68 Crh.            3          0               3     6
# 3                          NaN            3          0               3     6
# 4                          NaN            3          0               3     6
# ...                        ...          ...        ...             ...   ...
# 1373                       NaN            2          0               2     3
# 1374                       NaN            2          0               2     3
# 1375                       NaN            2          0               2     3
# 1376                       NaN            2          0               2     3
# 1377                       NaN            3          0               3     4
#
# [1378 rows x 9 columns]

# %%
df.insert(9, 'Theoritical', 3)
df.insert(10, 'Practical', 0)
df.insert(11, 'Course Credit', 3)
df.insert(12, 'ECTS', 5)

# %%
unavailable_courses = set()
for row_idx in df.index:
    course_code = df.iloc[row_idx, 0]
    course_title = df.iloc[row_idx, 1]
    title_indices = list(course_df.iloc[:, 2][course_df.iloc[:, 2] == course_title].index)
    code_indices = list(course_df.iloc[:, 1][course_df.iloc[:, 1] == course_code].index)
    if len(title_indices) >= 1:
        title_index = title_indices[0]
        if course_title == course_df.iloc[title_index, 2]:
            df.iloc[row_idx, 0] = course_df.iloc[title_index, 1]
            df.iloc[row_idx, 9] = course_df.iloc[title_index, 5]
            df.iloc[row_idx, 10] = course_df.iloc[title_index, 6]
            df.iloc[row_idx, 11] = course_df.iloc[title_index, 7]
            df.iloc[row_idx, 12] = course_df.iloc[title_index, 8]
            continue
    elif len(code_indices) >= 1:
        code_index = code_indices[0]
        if course_code == course_df.iloc[code_index, 1]:
            df.iloc[row_idx, 1] = course_df.iloc[code_index, 2]
            df.iloc[row_idx, 9] = course_df.iloc[code_index, 5]
            df.iloc[row_idx, 10] = course_df.iloc[code_index, 6]
            df.iloc[row_idx, 11] = course_df.iloc[code_index, 7]
            df.iloc[row_idx, 12] = course_df.iloc[code_index, 8]
    else: unavailable_courses.add((course_code, course_title))

# %%
for idx in df.index:
    if df.iloc[idx, 0] == 'PHYS 204':
        df.iloc[idx, 0] = 'PHYS 104'
    df.iloc[idx, 2] = df.iloc[idx, 0].split()[1][0]
df
# Out:
#       Course Code                                      Course Title  \
# 0          IE 316                             Engineering Economics
# 1         MGT 201                          Principles of Management
# 2        PHYS 104  Physics II - Electromagnetics and Modern Physics
# 3         UNI 123               Textual Analysis and Effective Com.
# 4        ENGR 244                             Engineering Materials
# ...           ...                                               ...
# 49342     ITM 416             Special Topics in International Trade
# 49343     GIR 304                           Organizational Behavior
# 49344     ITM 310                           Supply Chain Management
# 49345     ITM 406                          Global Business Strategy
# 49346     UNI 116             Turkish for International Students II
#
#       Course Year  Student Number Department Code   Course Level Letter Grade  \
# 0               3             713              IE  Undergraduate            A
# 1               2             713             ITM  Undergraduate            A
# 2               1             713              IE  Undergraduate            A
# 3               1             713              IE  Undergraduate            A
# 4               2             713              IE  Undergraduate           A-
# ...           ...             ...             ...            ...          ...
# 49342           4            2315             MGT  Undergraduate           B-
# 49343           3            2315             MGT  Undergraduate           B-
# 49344           3            2315             MGT  Undergraduate            C
# 49345           4            2315             MGT  Undergraduate            C
# 49346           1            2315             MGT  Undergraduate           C+
#
#            Status       Semester Theoritical  Practical  Course Credit  ECTS
# 0      Successful  2014 - Spring           2          2              3     5
# 1      Successful    2013 - Fall           3          0              3     5
# 2      Successful  2012 - Spring           3          2              4     6
# 3      Successful  2012 - Spring           3          0              3     5
# 4      Successful  2013 - Spring           3          0              3     5
# ...           ...            ...         ...        ...            ...   ...
# 49342  Successful  2014 - Spring           3          0              3     5
# 49343  Successful  2014 - Spring           3          0              3     5
# 49344  Successful  2014 - Spring           3          0              3     5
# 49345  Successful  2014 - Spring           3          2              4     8
# 49346  Successful  2014 - Spring           3          0              3     5
#
# [49347 rows x 13 columns]

# %%
print('The following courses are not offered now. Graduate Courses are not scraped from website', len(unavailable_courses))
print('Except Turkish for International Students, everything else is not offered now.')
for c, t in unavailable_courses:
    print(c, t)
# Out:
# The following courses are not offered now. Graduate Courses are not scraped from website 301
# Except Turkish for International Students, everything else is not offered now.
# HUK 555 Marka Hukukunda Hükümsüzlük Davaları
# MTS 517 Mass Media and Power in Turkey
# ECE 516 System Optimizations
# CULT 516 Visual Culture
# HUK 662 Türk Borçlar Kanu.Yeni.Değiş.Denet.
# UNI 201 Formations of Modern Turkey I
# HUK 522 Hükümet Sistemleri
# HUK 566 İş Güvencesi ve İşe İade Davaları
# MGT 585 Üretim Yönetimi
# HUK 511 Osmanlı Anayasa Hukuku
# MGT 572 İleri Düzeyde İşletme Yön. Sem.
# UNI 216 Turkish for International Students IV
# ISE 531 Probability and Statistics for Engineers
# BGM 574 Bilgi Güvenliği Yönetimi
# ECE 537 Optoelectronic Devices and Lasers
# CULT 513 Gender Theory
# HUK 563 İş Akitlerinin Türleri ve Sona Ermesi
# HUK 536 Özgürlük Kavramı ve Teorileri II
# SOC 581 Religion and Politics in Turkey
# MGT 545 İnteraktif Pazarlama
# MGT 580 Yöneticiler İçin Hukuk
# UNI 115 Turkish for International Students I
# MTS 581 Texts in Ottoman Turkish

# %%
unweight_grades = []
for row_idx in df.index:
    if df.iloc[row_idx, 6] in ['IA', 'S', 'U', 'NP', 'TP']:
        unweight_grades.append(row_idx)        
for idx in unweight_grades:
    df.drop(idx, inplace=True)
df.index = range(len(df))
df
# Out:
#       Course Code                                      Course Title  \
# 0          IE 316                             Engineering Economics
# 1         MGT 201                          Principles of Management
# 2        PHYS 104  Physics II - Electromagnetics and Modern Physics
# 3         UNI 123               Textual Analysis and Effective Com.
# 4        ENGR 244                             Engineering Materials
# ...           ...                                               ...
# 49342     ITM 416             Special Topics in International Trade
# 49343     GIR 304                           Organizational Behavior
# 49344     ITM 310                           Supply Chain Management
# 49345     ITM 406                          Global Business Strategy
# 49346     UNI 116             Turkish for International Students II
#
#       Course Year  Student Number Department Code   Course Level Letter Grade  \
# 0               3             713              IE  Undergraduate            A
# 1               2             713             ITM  Undergraduate            A
# 2               1             713              IE  Undergraduate            A
# 3               1             713              IE  Undergraduate            A
# 4               2             713              IE  Undergraduate           A-
# ...           ...             ...             ...            ...          ...
# 49342           4            2315             MGT  Undergraduate           B-
# 49343           3            2315             MGT  Undergraduate           B-
# 49344           3            2315             MGT  Undergraduate            C
# 49345           4            2315             MGT  Undergraduate            C
# 49346           1            2315             MGT  Undergraduate           C+
#
#            Status       Semester Theoritical  Practical  Course Credit  ECTS
# 0      Successful  2014 - Spring           2          2              3     5
# 1      Successful    2013 - Fall           3          0              3     5
# 2      Successful  2012 - Spring           3          2              4     6
# 3      Successful  2012 - Spring           3          0              3     5
# 4      Successful  2013 - Spring           3          0              3     5
# ...           ...            ...         ...        ...            ...   ...
# 49342  Successful  2014 - Spring           3          0              3     5
# 49343  Successful  2014 - Spring           3          0              3     5
# 49344  Successful  2014 - Spring           3          0              3     5
# 49345  Successful  2014 - Spring           3          2              4     8
# 49346  Successful  2014 - Spring           3          0              3     5
#
# [49347 rows x 13 columns]

# %%
type_ = course_df.pop('Type')
# Out:
# 0                       Required
# 1                       Required
# 2                       Required
# 3                       Required
# 4                       Required
#                   ...
# 1373           Alan Dışı Seçmeli
# 1374           Alan Dışı Seçmeli
# 1375           Alan Dışı Seçmeli
# 1376           Alan Dışı Seçmeli
# 1377    SOP XXX Bölüm Seçmeli II
# Name: Type, Length: 1378, dtype: object

# %%
df.insert(2, 'Type', type_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-16347e5c97df> in <module>
# ----> 1 df.insert(2, 'Type', type_)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert Type, already exists

# %%
df.to_csv('cleaned_dataset.csv', index=False)
